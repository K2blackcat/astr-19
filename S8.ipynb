# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,100)

def my_sin(x):
    return np.sin(x)
def my_cos(x):
    return np.cos(x)

# %%
fig, axes = plt.subplots(1, 2, figsize = (10, 4))

axes[0].plot(x,my_sin(x))
axes[0].set_title('sin(x)')
axes[0].set_xlabel('x')
axes[0].set_ylabel('sin(x)')

axes[1].plot(x,my_cos(x))
axes[1].set_title('cos(x)')
axes[1].xlabel('x')
axes[1].ylabel('cos(x)')

plt.tight-layout()
plt.savefig("sin_cos_plot.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       3 axes[0].plot(x,my_sin(x))
#       4 axes[0].set_title('sin(x)')
# ----> 5 axes[0].xlabel('x')
#       6 axes[0].ylabel('sin(x)')
#       8 axes[1].plot(x,my_cos(x))
#
# AttributeError: 'Axes' object has no attribute 'xlabel'
